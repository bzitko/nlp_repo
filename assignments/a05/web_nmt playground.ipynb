# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
from argparse import Namespace
import string
import re
import random
import pandas as pd

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

from tqdm.notebook import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
args = Namespace(
    # Data and path information
    dataset_csv="eng_fra_simplest.csv",
    model_filename="model.pth",
    # Model hyper parameter
    source_embedding_size=64,
    target_embedding_size=64,
    encoding_size=64,    
    # Training hyper parameter
    num_epochs=100,
    learning_rate=5e-4,
    batch_size=128,
    seed=1337,
    early_stop=5,
    # Runtime hyper parameter
    teach_ratio=0.1
)

args.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
args.device
# Out:
# device(type='cpu')

# %%
df = pd.read_csv(args.dataset_csv)
df
# Out:
#        Unnamed: 0                       source_language  split  \
# 0               0        he 's the cutest boy in town .  train
# 1               1                   he 's a nonsmoker .  train
# 2               2               he 's smarter than me .  train
# 3               3            he 's a lovely young man .  train
# 4               4     he 's three years older than me .  train
# ...           ...                                   ...    ...
# 13057       13057                 you are n't invited .   test
# 13058       13058          you are always watching tv .   test
# 13059       13059  you are trusted by every one of us .   test
# 13060       13060             you are blinded by love .   test
# 13061       13061               you are a good person .   test
#
#                                  target_language
# 0      c'est le garçon le plus mignon en ville .
# 1                            il est non-fumeur .
# 2              il est plus intelligent que moi .
# 3                c'est un adorable jeune homme .
# 4               il a trois ans de plus que moi .
# ...                                          ...
# 13057                  vous n'êtes pas invités .
# 13058        tu regardes tout le temps la télé .
# 13059         chacun de nous te fait confiance .
# 13060            vous êtes aveuglé par l'amour .
# 13061              tu es une chouette gonzesse .
#
# [13062 rows x 4 columns]

# %%
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1


class Vocab(object):

    def __init__(self, tokens=None, pad_token=None, unk_token=None, begin_seq_token=None, end_seq_token=None):
        self._tok2idx = {}
        self._idx2tok = {}
        
        self.pad_token = pad_token
        self.pad_idx = None
        if pad_token is not None:
            self.pad_idx = self.add_token(pad_token)
        
        self.unk_token = unk_token
        self.unk_idx = None
        if unk_token is not None:
            self.unk_idx = self.add_token(unk_token)

        self.begin_seq_token = begin_seq_token
        self.begin_seq_idx = None
        if begin_seq_token is not None:
            self.begin_seq_idx = self.add_token(begin_seq_token)

        self.end_seq_token = end_seq_token
        self.end_seq_idx = None
        if end_seq_token is not None:
            self.end_seq_idx = self.add_token(end_seq_token)

        if tokens is not None:
            self.add_tokens(tokens)

    def add_token(self, token):
        if token not in self._tok2idx:
            idx = len(self._tok2idx)
            self._tok2idx[token] = idx
            self._idx2tok[idx] = token
            return idx
        return self._tok2idx[token]

    def add_tokens(self, tokens):
        return [self.add_token(token) for token in tokens]

    def ordered_indices(self):
        return sorted(self._idx2tok)

    def ordered_tokens(self):
        for i in sorted(self._idx2tok):
            yield self._idx2tok[i]

    def __getitem__(self, token_or_idx):
        if isinstance(token_or_idx, str):
            return self._tok2idx.get(token_or_idx, self.unk_idx)
        if isinstance(token_or_idx, int):
            return self._idx2tok.get(token_or_idx, self.unk_token)

    def __len__(self):
        return len(self._tok2idx)

    def __iter__(self):
        for i in sorted(self._idx2tok):
            yield self._idx2tok[i]

    def info(self):
        txt = f"Vocabulary size:{len(self)}"
        for i in range(min(4, len(self))):
            txt += f" {self[i]}:{i}"
        txt += " ..."
        print(txt)

source_words = {w for sent in df[df.split == "train"].source_language for w in sent.split()}
source_vocab = Vocab(sorted(source_words), pad_token="<PAD>", unk_token="<UNK>", begin_seq_token="<BOS>", end_seq_token="<EOS>")

target_words = {w for sent in df[df.split == "train"].target_language for w in sent.split()}
target_vocab = Vocab(sorted(target_words), pad_token="<PAD>", unk_token="<UNK>", begin_seq_token="<BOS>", end_seq_token="<EOS>")

# %%
# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters


def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s

def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
    lines = open('%s-%s.txt' % (lang1, lang2), encoding='utf-8').\
        read().strip().split('\n')

    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %% [markdown]
# # Data

# %%
MAX_LENGTH = 10

eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s ",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re "
)


def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH and \
        p[1].startswith(eng_prefixes)


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

def prepareData(lang1, lang2, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs


input_lang, output_lang, pairs = prepareData('eng', 'fra', True)
pair = random.choice(pairs)
print(pair)
# Out:
# Reading lines...
# Read 135842 sentence pairs
# Trimmed to 10599 sentence pairs
# Counting words...
# Counted words:
# fra 4345
# eng 2803
# ['vous etes aveuglee par l amour .', 'you are blinded by love .']

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device)# .view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

tensorsFromPair(pair)


class Vectorizer():

    def __init__(self, vocab, max_size=-1):
        self.vocab = vocab
        self.max_size = max_size

    def vectorize(self, tokens, seq=True):
        indices = [self.vocab[tok] for tok in tokens]
        if seq:
            indices = [self.vocab.begin_seq_idx] + indices + [self.vocab.end_seq_idx]
        
        if self.max_size >= 0:
            indices = indices[:self.max_size]
            indices += [self.vocab.pad_idx] * (self.max_size - len(indices))
        return torch.LongTensor(indices)    

#source_max_size = max(len(sent.split()) for sent in df.source_language)
source_vectorizer = Vectorizer(source_vocab)

#target_max_size = max(len(sent.split()) for sent in df.target_language)
target_vectorizer = Vectorizer(target_vocab)

datapoint = df.iloc[0]
source_vectorizer.vectorize(datapoint.source_language.split())
target_vectorizer.vectorize(datapoint.target_language.split())


class NMTDataset(torch.utils.data.Dataset):

    def __init__(self, df, source_vectorizer, target_vectorizer):
        self.df = df
        self.source_vectorizer = source_vectorizer
        self.target_vectorizer = target_vectorizer
        self._lookup = {split: self.df[self.df.split == split] for split in set(self.df.split)}
        self.set_split("train")
        
    def set_split(self, split):
        self._target_split = split
        self._target_df = self._lookup[split]

    def vectorize_source(self, sent):
        return self.source_vectorizer.vectorize(sent.split(), seq=True)

    def vectorize_target(self, sent):
        return self.target_vectorizer.vectorize(sent.split(), seq=True)

    def __getitem__(self, idx):
        data = self.df.iloc[idx]
        return self.vectorize_source(data.source_language), self.vectorize_target(data.target_language)
        
    def __len__(self):
        return len(self._target_df)

    def get_num_batches(self, batch_size):
        return len(self) // batch_size



def generate_batches(dataset, batch_size, shuffle=True):

    def collate_fn(batch):
        x, y = [], []
        for xi, yi in batch:
            x.append(xi)
            y.append(yi)
        x = torch.nn.utils.rnn.pad_sequence(x, padding_value=dataset.source_vectorizer.vocab.pad_idx).transpose(1, 0)
        y = torch.nn.utils.rnn.pad_sequence(y, padding_value=dataset.target_vectorizer.vocab.pad_idx).transpose(1, 0)
        return x, y

    for x, y in torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, collate_fn=collate_fn, drop_last=True):
        yield x.to(args.device), y.to(args.device)

dataset = NMTDataset(df, source_vectorizer, target_vectorizer)

assert len(dataset) == 9138
assert len(dataset[0]) == 2

for x, y in generate_batches(dataset, batch_size=3):
    print(x)
    print(y)
    break
# Out:
# tensor([[   2, 1371,    8, 2868, 1257, 3015,    7,  271, 2877, 2732, 1801, 1731,
#            14,    3],
#         [   2, 1371,    8, 1818, 2262,   14,    3,    0,    0,    0,    0,    0,
#             0,    0],
#         [   2, 1371,    8,  202,   14,    3,    0,    0,    0,    0,    0,    0,
#             0,    0]])
# tensor([[   2, 2279, 4283, 4575,  877, 3656, 4576, 4699, 4485, 2498, 2847, 3491,
#             9,    3],
#         [   2, 2279, 2985, 4283, 3217, 4555,    9,    3,    0,    0,    0,    0,
#             0,    0],
#         [   2, 2279, 4283, 4267,    9,    3,    0,    0,    0,    0,    0,    0,
#             0,    0]])

# %% [markdown]
# # Encoder

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.rnn = nn.GRU(hidden_size, hidden_size, batch_first=True)

    def forward(self, input, hidden=None):
        embedded = self.embedding(input)# .view(1, 1, -1)
        output = embedded
        output, hidden = self.rnn(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)


x, y = tensorsFromPair(pair)
hidden_size=64
encoder = EncoderRNN(input_lang.n_words, hidden_size)
y_hat, h = encoder(x, None)



encoder = EncoderRNN(len(dataset.source_vectorizer.vocab), args.source_embedding_size)
x, y = next(generate_batches(dataset, batch_size=3))
x.shape, y.shape

y_hat, h = encoder(x)
print(y_hat.shape)
print(h.shape)
# Out:
# torch.Size([3, 9, 64])
# torch.Size([1, 3, 64])

# %% [markdown]
# # Decoder

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.rnn = nn.GRU(hidden_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=-1)

    def forward(self, input, hidden=None):
        output = self.embedding(input) # .view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.rnn(output, hidden)
        output = self.fc(output)
        output = self.softmax(output)   
        return output, hidden

    def generate(self, input, hidden=None, size=-1):
        output = self.embedding(input)
        output = F.relu(output)

        outputs = [output]
        for _ in range(size - 1):
            output, hidden = self.rnn(output, hidden)
            outputs.append(output)
            output = F.relu(output)

        outputs = torch.cat(outputs, dim=1)
        outputs = self.fc(outputs)
        outputs = self.softmax(outputs)           
        return outputs, hidden


    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)


encoder = EncoderRNN(len(dataset.source_vectorizer.vocab), args.source_embedding_size)
decoder = DecoderRNN(args.target_embedding_size, len(dataset.target_vectorizer.vocab))
x, y = next(generate_batches(dataset, batch_size=3))

y_hat, h = encoder(x)
print(y_hat.shape)
print(h.shape)
y_hat, h = decoder(y, h)


y_hat, h = decoder.generate(y[:,[0]], size=y.shape[1])
print(y.shape)
print(y_hat.shape)
print(h.shape)
# Out:
# torch.Size([3, 11, 64])
# torch.Size([1, 3, 64])
# torch.Size([3, 17])
# torch.Size([3, 17, 4911])
# torch.Size([1, 3, 64])

# %% [markdown]
# # Attention Decoder

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# # D' Training

# %%
# early stopping
def early_stop(train_state, model):
    val_loss = train_state["val_loss"]
    if len(val_loss) < 2:
        torch.save(model.state_dict(), args.model_filename)
        return False
    
    if val_loss[-1] < val_loss[-2]:
        torch.save(model.state_dict(), args.model_filename)
    
    if len(val_loss) >= args.early_stop:
        val_loss =  val_loss[-args.early_stop:]
        return all(val_loss[i] < val_loss[i + 1] 
                   for i in range(args.early_stop - 1))

    return False

def compute_accuracy(y_hat, y):
    _, y_hat_indices = y_hat.max(dim=-1)
    y_hat_indices = y_hat_indices.ravel()
    y = y.ravel()
    n_correct = torch.eq(y_hat_indices, y).sum().item()
    return n_correct / len(y_hat_indices) * 100    


def compute_loss(y_hat, y):
    y_hat = F.log_softmax(y_hat, dim=-1)
    losses = []
    for b_y_hat, b_y in zip(y_hat, y):
        lv = loss_func(b_y_hat, b_y)
        losses.append(lv)
    return torch.stack(losses).mean()    

# encoder-decoder
encoder = EncoderRNN(len(dataset.source_vectorizer.vocab), args.source_embedding_size).to(args.device)
decoder = DecoderRNN(args.target_embedding_size, len(dataset.target_vectorizer.vocab)).to(args.device)
                     
# seed
torch.manual_seed(args.seed)
torch.cuda.manual_seed_all(args.seed)

# loss, optimizer, scheduler
loss_func = torch.nn.NLLLoss(ignore_index=dataset.target_vectorizer.vocab.pad_idx)
encoder_optimizer = torch.optim.Adam(encoder.parameters(), lr=args.learning_rate)
decoder_optimizer = torch.optim.Adam(decoder.parameters(), lr=args.learning_rate)

#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, mode='min', factor=0.5, patience=1)

# progress bars
epoch_bar = tqdm(desc='epochs', total=args.num_epochs, position=0)
dataset.set_split('train')
train_bar = tqdm(desc='train', total=dataset.get_num_batches(args.batch_size), position=1, leave=True)
dataset.set_split('val')
val_bar = tqdm(desc='val', total=dataset.get_num_batches(args.batch_size), position=1, leave=True)

# train state tracker
train_state = {"train_loss": [],
               "train_acc": [],
               "val_loss": [],
               "val_acc": [],}



try:
    for epoch_index in range(args.num_epochs):
        dataset.set_split('train')
        batch_generator = generate_batches(dataset, batch_size=args.batch_size)
        running_loss = running_acc = 0.0
        
        encoder.train()
        decoder.train()
    
        for batch_index, (x, y) in enumerate(batch_generator):
            encoder.zero_grad()
            decoder.zero_grad()

            if torch.rand(1).item() > args.teach_ratio:
                y_hat, he = encoder(x)
                y_hat, hd = decoder(y, he.detach().clone())
            else:
                y_hat, he = encoder(x)
                y_hat, hd = decoder.generate(y[:,[0]], he.detach().clone(), y.shape[1])

            loss = compute_loss(y_hat, y)
            loss_t = loss.item()
            running_loss += (loss_t - running_loss) / (batch_index + 1)

            loss.backward()
            encoder_optimizer.step()
            decoder_optimizer.step()

            acc_t = compute_accuracy(y_hat, y)
            running_acc += (acc_t - running_acc) / (batch_index + 1)

            # update bar
            train_bar.set_postfix(loss=running_loss, acc=running_acc, epoch=epoch_index)
            train_bar.update()

        train_state['train_loss'].append(running_loss)
        train_state['train_acc'].append(running_acc)        

        # Iterate over val dataset
        # setup: batch generator, set loss and acc to 0; set eval mode on
        dataset.set_split('val')
        batch_generator = generate_batches(dataset, batch_size=args.batch_size)
        running_loss = running_acc = 0.0
        
        encoder.eval()
        decoder.eval()

        for batch_index, (x, y) in enumerate(batch_generator):
            if torch.rand(1).item() > args.teach_ratio:
                y_hat, he = encoder(x)
                y_hat, hd = decoder(y, he.detach().clone())
            else:
                y_hat, he = encoder(x)
                y_hat, hd = decoder.generate(y[:,[0]], he.detach().clone(), y.shape[1])

            loss = compute_loss(y_hat, y)
            loss_t = loss.item()
            running_loss += (loss_t - running_loss) / (batch_index + 1)

            acc_t = compute_accuracy(y_hat, y)
            running_acc += (acc_t - running_acc) / (batch_index + 1)

            # update bar
            val_bar.set_postfix(loss=running_loss, acc=running_acc, epoch=epoch_index)
            val_bar.update()

        train_state['val_loss'].append(running_loss)
        train_state['val_acc'].append(running_acc)   

        if early_stop(train_state, decoder):
            print("Early stopping")
            break
        # scheduler.step(train_state['val_loss'][-1])

        train_bar.n = 0
        val_bar.n = 0
        epoch_bar.update()

except KeyboardInterrupt:
    print("Exiting loop")
# Out:
# epochs:   0%|          | 0/100 [00:00<?, ?it/s]
# train:   0%|          | 0/71 [00:00<?, ?it/s]
# val:   0%|          | 0/15 [00:00<?, ?it/s]

# %% [markdown]
# # Testing

# %%
#decoder.load_state_dict(torch.load(args.model_filename))


loss_func = torch.nn.NLLLoss()

dataset.set_split('test')
batch_generator = generate_batches(dataset, batch_size=args.batch_size)

running_loss = 0.
running_acc = 0.

encoder.eval()
decoder.eval()
for batch_index, (x, y) in enumerate(batch_generator):
    y_hat, he = encoder(x)
    y_hat, hd = decoder(y, he)
    
    # compute the loss
    loss = compute_loss(y_hat, y)
    loss_t = loss.item()
    running_loss += (loss_t - running_loss) / (batch_index + 1)

    # compute the accuracy
    acc_t = compute_accuracy(y_hat, y)
    running_acc += (acc_t - running_acc) / (batch_index + 1)

print(f"Test loss: {running_loss:.4f}")
print(f"Test Accuracy: {running_acc:.4f}")
# Out:
# Test loss: 8.1676
# Test Accuracy: 11.6598

# %%
sent = "i love you ."


def translate(sent):
    x = source_vectorizer.vectorize(sent.split())
    y_hat, hidden = encoder(x)
    hidden = hidden.unsqueeze(0)
    y = torch.tensor([target_vocab.begin_seq_idx]).unsqueeze(0)
    output, _ = decoder.generate(y, hidden=hidden, size=100)
    output = output.squeeze().argmax(dim=1)
    words = []
    for i in output:
        i = i.item()
        if i == target_vocab.end_seq_idx:
            break
        if i == target_vocab.begin_seq_idx:
            continue
        words.append(target_vocab[i])
    return " ".join(words)


for sent in df.source_language:
    print(sent, translate(sent))
# Out:
# he 's the cutest boy in town . je suis suis . .
# he 's a nonsmoker . je suis suis . .
# he 's smarter than me . je suis suis . .
# he 's a lovely young man . je suis suis . .
# he 's three years older than me . je suis suis . .
# he 's washing your car . je suis suis . .
# he 's your typical workaholic . je suis suis . .
# he 's waiting for you at home . je suis suis . .
# he 's a historian . je suis suis . .
# he 's studying . je suis suis . .
# he 's down to earth . je suis suis . .
# he 's starting to feel desperate . je suis suis . .
# he 's sketching an apple . je suis suis . .
# he 's worried about the result . je suis suis . .
# he 's out of town . je suis suis . .
# he 's a freelance journalist . je suis suis . .
# he 's afraid of snakes . je suis suis . .
# he 's nothing more than a common thug . je suis suis . .
# he 's a journalist . je suis suis . .
# he 's waiting for the train to leave . je suis suis . .
# he 's not available . je suis suis . .
# he 's very young . he 's much younger than tom . je suis suis . .
# he 's waiting for you at home . je suis suis . .
# he 's perfect at everything . je suis suis . .
# he 's eight years old . je suis suis . .
# he 's a notorious liar . je suis suis . .
# he 's ruthless . je suis suis . .
# he 's kind of cute , is n't he ? je suis suis . .
# he 's lazy . je suis suis . .
# he 's looking at you . je suis suis . .
# he 's our only suspect . je suis suis . .
# he 's tickled pink . je suis suis . .
# he 's a university student . je suis suis . .
# he 's not very good at it . je suis suis . .
# he 's used to speaking in public . je suis suis . .
# he 's a hunk . je suis suis . .
# he 's wide awake . je suis suis . .
# he 's not worthy of you . je suis suis . .
# he 's smart . je suis suis . .
# he 's my partner . je suis suis . .
# he 's stronger than you . je suis suis . .
# he 's not always happy . je suis suis . .
# he 's a bigot . je suis suis . .
# he 's addicted . je suis suis . .
# he 's got the new technique down pat . je suis suis . .
# he 's not good at remembering names . je suis suis . .
# he 's here trying to stir up trouble . je suis suis . .
# he 's not my type . je suis suis . .
# he 's very influential in the world of medicine . je suis suis . .
# he 's always chasing girls . je suis suis . .
# he 's a little taller than you are . je suis suis . .
# he 's not supposed to be here . je suis suis . .
# he 's just not the person i thought he was . je suis suis . .
# he 's the laziest person i know . je suis suis . .
# he 's waiting for you at home . je suis suis . .
# he 's a control freak . je suis suis . .
# he 's afraid of making mistakes . je suis suis . .
# he 's rich and powerful . je suis suis . .
# he 's an author . je suis suis . .
# he 's an opera lover . je suis suis . .
# he 's acting on his own . je suis suis . .
# he 's older , but no wiser . je suis suis . .
# he 's short and fat . je suis suis . .
# he 's somewhere in the park . je suis suis . .
# he 's greedy and lazy . je suis suis . .
# he 's already married . je suis suis . .
# he 's loaded . je suis suis . .
# he 's more than likely to be late . je suis suis . .
# he 's a typical japanese man . je suis suis . .
# he 's agreed to do the job . je suis suis . .
# he 's not at all afraid of snakes . je suis suis . .
# he 's very intelligent . je suis suis . .
# he 's curious about everything . je suis suis . .
# he 's a bigot . je suis suis . .
# he 's english . je suis suis . .
# he 's your son . je suis suis . .
# he 's not sick . je suis suis . .
# he 's right behind you . je suis suis . .
# he 's a rather rare individual . je suis suis . .
# he 's a man of his word . je suis suis . .
# he 's your friend . je suis suis . .
# he 's a good boy . je suis suis . .
# he 's good . je suis suis . .
# he 's the one who told me about that . je suis suis . .
# he 's always looking at you . je suis suis . .
# he 's the black sheep of the family . je suis suis . .
# he 's skilled at videogames . je suis suis . .
# he 's a ghostwriter . je suis suis . .
# he 's sound asleep . je suis suis . .
# he 's writing his diary . je suis suis . .
# he 's a hunk . je suis suis . .
# he 's open-minded . je suis suis . .
# he 's drunk . je suis suis . .
# he 's a tycoon . je suis suis . .
# he 's never hit me before . je suis suis . .
# he 's in danger . je suis suis . .
# he 's on his last legs . je suis suis . .
# he 's my old drinking buddy . je suis suis . .
# he 's so cute . je suis suis . .
# he 's attracted to black women . je suis suis . .
# he 's gone into hiding . je suis suis . .
# he 's very understanding . je suis suis . .
# he 's addicted to junk food . je suis suis . .
# he 's got what it takes to make it in the business world . je suis suis . .
# he 's too drunk . je suis suis . .
# he 's going to join our club . je suis suis . .
# he 's such a jerk . je suis suis . .
# he 's been drinking beer . je suis suis . .
# he 's looking at you . je suis suis . .
# he 's here to protect you . je suis suis . .
# he 's a bigot . je suis suis . .
# he 's looking good . je suis suis . .
# he 's as blind as a bat . je suis suis . .
# he 's right behind you . je suis suis . .
# he 's a very nice boy . je suis suis . .
# he 's worried that he might be late . je suis suis . .
# he 's a slob . je suis suis . .
# he 's not as old as my brother . je suis suis . .
# he 's not in . je suis suis . .
# he 's on the dance floor . je suis suis . .
# he 's demented . je suis suis . .
# he 's open-minded . je suis suis . .
# he 's young and single . je suis suis . .
# he 's not a bad guy . je suis suis . .
# he 's a very nice boy . je suis suis . .
# he 's not at home . je suis suis . .
# he 's so young . je suis suis . .
# he 's not rich , but he 's happy . je suis suis . .
# he 's very ill . je suis suis . .
# he 's the chairman of the committee . je suis suis . .
# he 's very honest , so we can depend on him . je suis suis . .
# he 's always breaking into our conversation . je suis suis . .
# he 's incredibly stupid . je suis suis . .
# he 's a bit naive . je suis suis . .
# he 's not my cousin . je suis suis . .
# he 's the class clown . je suis suis . .
# he 's about to finish reading the book . je suis suis . .
# he 's very fond of walking . je suis suis . .
# he 's so stupid . je suis suis . .
# he 's a bit jealous . je suis suis . .
# he 's helping me . je suis suis . .
# he 's my friend . je suis suis . .
# he 's a southpaw . je suis suis . .
# he 's shy , and never speaks unless spoken to . you have to talk to him . je suis suis . .
# he 's my husband . je suis suis . .
# he 's a very nice boy . je suis suis . .
# he 's too trusting . je suis suis . .
# he 's one of the best . je suis suis . .
# he 's never been abroad in his life . je suis suis . .
# he 's hungry and thirsty . je suis suis . .
# he 's the one who touched me . je suis suis . .
# he 's handsome and charming . je suis suis . .
# he 's a cardiologist . je suis suis . .
# he 's too drunk . je suis suis . .
# he 's incredibly talented . je suis suis . .
# he 's got an uncle who works in a bank . je suis suis . .
# he 's coming . je suis suis . .
# he 's in pain . je suis suis . .
# he 's out of town . je suis suis . .
# he 's allergic to cats . je suis suis . .
# he 's raking it in . je suis suis . .
# he 's playing with my cat . je suis suis . .
# he 's henpecked . je suis suis . .
# he 's still alive . je suis suis . .
# he 's extremely happy . je suis suis . .
# he 's not young anymore . je suis suis . .
# he 's such a great guy . je suis suis . .
# he 's about to leave . je suis suis . .
# he 's not ready . je suis suis . .
# he 's about to go . je suis suis . .
# he 's a newcomer . je suis suis . .
# he 's very honest , so we can rely on him . je suis suis . .
# he 's addicted to heroin . je suis suis . .
# he 's feeling much better . je suis suis . .
# he 's doing his german homework . je suis suis . .
# he 's very protective . je suis suis . .
# he 's a goal keeper . je suis suis . .
# he 's not worthy of you . je suis suis . .
# he 's my partner . je suis suis . .
# he 's kind of cute . je suis suis . .
# he 's a freshman . je suis suis . .
# he 's photogenic . je suis suis . .
# he 's smart and ambitious . je suis suis . .
# he 's under the chair . je suis suis . .
# he 's a very hard worker . je suis suis . .
# he 's a powerful sorcerer . je suis suis . .
# he 's always late for school . je suis suis . .
# he 's a filthy liar . je suis suis . .
# he 's no saint . je suis suis . .
# he 's a smart little feller . je suis suis . .
# he 's from georgia . je suis suis . .
# he 's lived here his entire life . je suis suis . .
# he 's now a college student . je suis suis . .
# he 's not perfect . je suis suis . .
# he 's on his way . je suis suis . .
# he 's their only child . je suis suis . .
# he 's brighter than they are . je suis suis . .
# he 's not a hero . je suis suis . .
# he 's going to love this . je suis suis . .
# he 's always complaining about the food . je suis suis . .
# he 's bulked up quite a bit since he 's been going to the gym . je suis suis . .
# he 's ahead in the race . je suis suis . .
# he 's the new ceo from the parent company in france . je suis suis . .
# he 's innocent . je suis suis . .
# he 's the prom king and she 's the prom queen . je suis suis . .
# he 's cleaning his rifle . je suis suis . .
# he 's not going . je suis suis . .
# he 's the one who touched me . je suis suis . .
# he 's out of practice . je suis suis . .
# he 's a short order cook . je suis suis . .
# he 's ashamed of his body . je suis suis . .
# he 's waiting for you at home . je suis suis . .
# he 's your friend . je suis suis . .
# he 's a fine young lad . je suis suis . .
# he 's a successful businessman . je suis suis . .
# he 's not breaking the law . je suis suis . .
# he 's young and attractive . je suis suis . .
# he 's an excellent kisser . je suis suis . .
# he 's a regular at the bars and pubs around here . je suis suis . .
# he 's done it before . je suis suis . .
# he 's decided to leave the company . je suis suis . .
# he 's asleep . je suis suis . .
# he 's in hot water . je suis suis . .
# he 's a talented young director . je suis suis . .
# he 's not going . je suis suis . .
# he 's ready to go . je suis suis . .
# he 's after me . je suis suis . .
# he 's been doing this for over twenty years . je suis suis . .
# he 's really quick . je suis suis . .
# he 's a senior . je suis suis . .
# he 's a very fine musician . je suis suis . .
# he 's two years older than mary is . je suis suis . .
# he 's a liar . je suis suis . .
# he 's so young . je suis suis . .
# he 's the same age as me . je suis suis . .
# he 's not serious . je suis suis . .
# he 's too old for me . je suis suis . .
# he 's here for me . je suis suis . .
# he 's in prison . je suis suis . .
# he 's a senior . je suis suis . .
# he 's a bartender . je suis suis . .
# he 's doing it right . je suis suis . .
# he 's a slowpoke . je suis suis . .
# he 's bulked up quite a bit since he 's been going to the gym . je suis suis . .
# he 's a professional photographer . je suis suis . .
# he 's interested in mayan prophecies . je suis suis . .
# he 's not allowed to leave the country . je suis suis . .
# he 's raking it in . je suis suis . .
# he 's a nervous wreck . je suis suis . .
# he 's the most likely to succeed . je suis suis . .
# he 's checking his cellphone . je suis suis . .
# he 's your son . je suis suis . .
# he 's a crybaby , just like always . je suis suis . .
# he 's not the brightest guy in the world . je suis suis . .
# he 's a young , impressionable teenager . je suis suis . .
# he 's your son . je suis suis . .
# he 's raking it in . je suis suis . .
# he 's not my father . je suis suis . .
# he 's a law-abiding citizen . je suis suis . .
# he 's a frat boy . je suis suis . .
# he 's a comedian . je suis suis . .
# he 's not like us . je suis suis . .
# he 's always running short of cash . je suis suis . .
# he 's a famous popular singer in japan . je suis suis . .
# he 's out now . je suis suis . .
# he 's not very good at it . je suis suis . .
# he 's never been in love before . je suis suis . .
# he 's a bit tipsy . je suis suis . .
# he 's not in . je suis suis . .
# he 's mumbling something . je suis suis . .
# he 's a salesman too . je suis suis . .
# he 's learning chinese . je suis suis . .
# he 's a grouch . je suis suis . .
# he 's working at his english . je suis suis . .
# he 's here to protect you . je suis suis . .
# he 's a lovely young man . je suis suis . .
# he 's only a couple of years younger than me . je suis suis . .
# he 's a nervous wreck . je suis suis . .
# he 's fluent in japanese . je suis suis . .
# he 's reading a novel right now . je suis suis . .
# he 's a late bloomer . je suis suis . .
# he 's had some very good results lately . je suis suis . .
# he 's an englishman . je suis suis . .
# he 's swiss . je suis suis . .
# he 's still sick in bed . je suis suis . .
# he 's always reading comics . je suis suis . .
# he 's addicted to drugs . je suis suis . .
# he 's a food critic . je suis suis . .
# he 's a smooth talker . je suis suis . .
# he 's always complaining about something . je suis suis . .
# he 's been waiting here for a long time . je suis suis . .
# he 's likely to be late . je suis suis . .
# he 's going to get fired . je suis suis . .
# he 's stronger than me . je suis suis . .
# he 's the one who helped me . je suis suis . .
# he 's a nerd . je suis suis . .
# he 's too old for her . je suis suis . .
# he 's allergic to cats . je suis suis . .
# he 's sitting in the waiting room . je suis suis . .
# he 's adorable . je suis suis . .
# he 's mad at his daughter . je suis suis . .
# he 's in big trouble . je suis suis . .
# he 's been teaching for 20 years . je suis suis . .
# he 's playing with my cat . je suis suis . .
# he 's here to spy on us . je suis suis . .
# he 's an author . je suis suis . .
# he 's a bit shy . je suis suis . .
# he 's a bartender . je suis suis . .
# he 's a very talented man . je suis suis . .
# he 's just buying time . je suis suis . .
# he 's away on business . je suis suis . .
# he 's a bit drunk . je suis suis . .
# he 's a man you can rely on . je suis suis . .
# he 's right behind you . je suis suis . .
# he 's dating my daughter . je suis suis . .
# he 's about to go . je suis suis . .
# he 's like a brother to me . je suis suis . .
# he 's such a jerk . je suis suis . .
# he 's not one of us . je suis suis . .
# he 's an expert with a slingshot . je suis suis . .
# he 's a movie buff . je suis suis . .
# he 's likely to come . je suis suis . .
# he 's going to sit here . je suis suis . .
# he 's a control freak . je suis suis . .
# he 's fresh out of college . je suis suis . .
# he 's unconscious . je suis suis . .
# he 's head over heels in love . je suis suis . .
# he 's the perfect man for you . je suis suis . .
# he 's more than likely to come . je suis suis . .
# he 's afraid of the sea . je suis suis . .
# he 's good at arithmetic . je suis suis . .
# he 's already left . je suis suis . .
# he 's wanted for grand theft auto . je suis suis . .
# he 's talking on the telephone . je suis suis . .
# he 's self-employed . je suis suis . .
# he 's not a very meticulous guy . je suis suis . .
# he 's a hopeless case . je suis suis . .
# he 's out of practice . je suis suis . .
# he 's a man you can rely on . je suis suis . .
# he 's so cute . je suis suis . .
# he 's waiting for you at home . je suis suis . .
# he 's been divorced for 2 years already . je suis suis . .
# he 's coming closer . je suis suis . .
# he 's waiting for you at home . je suis suis . .
# he 's got a headache . je suis suis . .
# he 's cunning and manipulative . je suis suis . .
# he 's no saint . je suis suis . .
# he 's a republican fundraiser . je suis suis . .
# he 's a slacker . je suis suis . .
# he 's digging his own grave . je suis suis . .
# he 's been waiting here for a long time . je suis suis . .
# he 's almost as tall as me . je suis suis . .
# he 's a gentleman . je suis suis . .
# he 's still alive . je suis suis . .
# he 's going to regret this . je suis suis . .
# he 's studying hard so he can pass the entrance exam . je suis suis . .
# he 's leaning on a cane . je suis suis . .
# he 's got lung cancer . je suis suis . .
# he 's scared to talk to me . je suis suis . .
# he 's a carbon copy of his father . je suis suis . .
# he 's everybody 's friend . je suis suis . .
# he 's eating lunch now . je suis suis . .
# he 's the one who 's lagging behind . je suis suis . .
# he 's at her side . je suis suis . .
# he 's screaming , not singing . je suis suis . .
# he 's afraid of making mistakes . je suis suis . .
# he 's in for a shock . je suis suis . .
# he 's a slacker . je suis suis . .
# he 's your father . je suis suis . .
# he 's my younger brother . je suis suis . .
# he 's nervous and easily frightened . je suis suis . .
# he 's always at home on mondays . je suis suis . .
# he 's very talented . je suis suis . .
# he 's just a liar . je suis suis . .
# he 's tall and slim . je suis suis . .
# he 's a teacher and so am i . je suis suis . .
# he 's the most popular boy in the class . je suis suis . .
# he 's very flexible . je suis suis . .
# he 's had many unhappy experiences . je suis suis . .
# he 's a cardiologist . je suis suis . .
# he 's now short of money . je suis suis . .
# he 's a kind person . je suis suis . .
# he 's a jesuit . je suis suis . .
# he 's a sophomore . je suis suis . .
# he 's deep in debt . je suis suis . .
# he 's thrilled with his new job . je suis suis . .
# he 's afraid of making mistakes . je suis suis . .
# he 's a singer that 's loved by everyone . je suis suis . .
# he 's annoying . je suis suis . .
# he 's my age . je suis suis . .
# he 's active and fit . je suis suis . .
# he 's not such a great writer and i think he knows it . je suis suis . .
# he 's going to cross the river . je suis suis . .
# he 's missed the boat . je suis suis . .
# he 's just kidding you . je suis suis . .
# he 's nervous and gets scared easily . je suis suis . .
# he 's a leading authority in his field . je suis suis . .
# he 's in big trouble . je suis suis . .
# he 's after me . je suis suis . .
# he 's definitely not coming . je suis suis . .
# he 's a strange guy . je suis suis . .
# he 's getting old . je suis suis . .
# he 's not sure he 's ready . je suis suis . .
# he 's reading a novel right now . je suis suis . .
# he 's too young to drink . je suis suis . .
# he 's different from before . je suis suis . .
# he 's an accredited representative of the canadian government . je suis suis . .
# he 's a friend of my brother 's . je suis suis . .
# he 's not going to visit you tomorrow . je suis suis . .
# he 's writing a long letter . je suis suis . .
# he 's doing it right . je suis suis . .
# he 's saving up to go to college . je suis suis . .
# he 's watching me . je suis suis . .
# he 's hungry for power . je suis suis . .
# he 's my friend . do you know him ? je suis suis . .
# he 's still single . je suis suis . .
# he 's a very nice boy . je suis suis . .
# he 's a student of japanese literature . je suis suis . .
# he 's doing his best . je suis suis . .
# he 's buying an old hat . je suis suis . .
# he 's really into soccer . je suis suis . .
# he 's a very fine musician . je suis suis . .
# he 's a tennis player . je suis suis . .
# he 's a cat lover . je suis suis . .
# he 's always at home on mondays . je suis suis . .
# he 's taking a shower . je suis suis . .
# he 's married . je suis suis . .
# he 's a man of many talents . je suis suis . .
# he 's looking for a job . je suis suis . .
# he 's hiding in the closet . je suis suis . .
# he 's after me . je suis suis . .
# he 's old and crazy . je suis suis . .
# he 's kind of shy . je suis suis . .
# he 's accustomed to traveling . je suis suis . .
# he 's a senior . je suis suis . .
# he 's very upset by this . je suis suis . .
# he 's an oceanographer . je suis suis . .
# he 's intimidated by beautiful women . je suis suis . .
# he 's waiting for you at home . je suis suis . .
# he 's an aristocrat . je suis suis . .
# he 's cruel and heartless . je suis suis . .
# he 's the one , is n't he ? je suis suis . .
# he 's not at all afraid of snakes . je suis suis . .
# he 's financially dependent on his wife . je suis suis . .
# he 's too slow . je suis suis . .
# he 's in the shower . je suis suis . .
# he 's in my class . je suis suis . .
# he 's after me . je suis suis . .
# he 's incredibly talented . je suis suis . .
# he 's addicted . je suis suis . .
# he 's hopelessly in love . je suis suis . .
# he 's my best friend . je suis suis . .
# he 's sitting in the waiting room . je suis suis . .
# he 's a bad influence . je suis suis . .
# he 's with his parents . je suis suis . .
# he 's in danger of being evicted . je suis suis . .
# he 's in prison . je suis suis . .
# he 's not in our group . je suis suis . .
# he 's the captain of a team . je suis suis . .
# he 's a great kisser . je suis suis . .
# he 's crying . je suis suis . .
# he 's sleeping like a baby . je suis suis . .
# he 's your typical workaholic . je suis suis . .
# he 's a foreign exchange student . je suis suis . .
# he 's good at what he does . je suis suis . .
# he 's never been in love before . je suis suis . .
# he 's always on time for his appointments . je suis suis . .
# he 's a bit naive . je suis suis . .
# he 's open and trusting . je suis suis . .
# he 's getting cold feet . je suis suis . .
# he 's sleeping off last night 's bender . je suis suis . .
# he 's an advocate of barefoot running . je suis suis . .
# he 's a good liar . je suis suis . .
# he 's really selfish . je suis suis . .
# he 's pushing fifty . je suis suis . .
# he 's not going . je suis suis . .
# he 's innocent . je suis suis . .
# he 's loaded . je suis suis . .
# he 's getting more and more stubborn with age . je suis suis . .
# he 's here trying to stir up trouble . je suis suis . .
# he 's love struck . je suis suis . .
# he 's rich . je suis suis . .
# he 's got the biggest eyebrows i 've ever seen . je suis suis . .
# he 's a professor of biology at harvard . je suis suis . .
# he 's very honest , so we can rely on him . je suis suis . .
# he 's better at it than i am . je suis suis . .
# he 's in his fifties . je suis suis . .
# he 's going to have a heart attack . je suis suis . .
# he 's not sure he wants to do this . je suis suis . .
# he 's at her side . je suis suis . .
# he 's a carbon copy of his father . je suis suis . .
# he 's out of town on business . je suis suis . .
# he 's behaving oddly . je suis suis . .
# he 's always worrying about his daughter . je suis suis . .
# he 's a southpaw . je suis suis . .
# he 's likely to be chosen . je suis suis . .
# he 's on his way home . je suis suis . .
# he 's a freshman . je suis suis . .
# he 's a bit of a drunkard . je suis suis . .
# he 's walking around in his underwear . je suis suis . .
# he 's broke . je suis suis . .
# he 's a well-known television personality . je suis suis . .
# he 's a stand-up guy . je suis suis . .
# he 's a gambler . je suis suis . .
# he 's in his late fifties . je suis suis . .
# he 's greedy and ruthless . je suis suis . .
# he 's in tokyo . je suis suis . .
# he 's been working all day long . je suis suis . .
# he 's my partner . je suis suis . .
# he 's kind of cute , is n't he ? je suis suis . .
# he 's got a boy-next-door look about him . je suis suis . .
# he 's the scapegoat . je suis suis . .
# he 's stronger than you . je suis suis . .
# he 's swimming now . je suis suis . .
# he 's a grown man . je suis suis . .
# he 's your son . je suis suis . .
# he 's on sentry duty . je suis suis . .
# he 's a freelance journalist . je suis suis . .
# he 's crazy about her . je suis suis . .
# he 's not in our group . je suis suis . .
# he 's your father . je suis suis . .
# he 's somewhat hard of hearing , so please speak louder . je suis suis . .
# he 's a slowpoke . je suis suis . .
# he 's rich , but he 's not happy . je suis suis . .
# he 's such a cold fish . je suis suis . .
# he 's stalling for time . je suis suis . .
# he 's in a state of shock . je suis suis . .
# he 's the only one who survived . je suis suis . .
# he 's just arrived . je suis suis . .
# he 's much younger than tom . je suis suis . .
# he 's an absolute fool . je suis suis . .
# he 's a computer nerd . je suis suis . .
# he 's such a sweetheart . je suis suis . .
# he 's afraid to dance . je suis suis . .
# he 's a bad liar . je suis suis . .
# he 's a democrat fundraiser . je suis suis . .
# he 's still single . je suis suis . .
# he 's a good person . je suis suis . .
# he 's a smooth talker . je suis suis . .
# he 's two years older than mary is . je suis suis . .
# he 's started writing a novel . je suis suis . .
# he 's a bit jealous . je suis suis . .
# he 's spending too much time watching tv . je suis suis . .
# he 's done this before . je suis suis . .
# he 's racking his brains about how to deal with the matter . je suis suis . .
# he 's nothing special . just another working stiff . je suis suis . .
# he 's a jerk . je suis suis . .
# he 's a cheat and a liar . je suis suis . .
# he 's kind of cute , is n't he ? je suis suis . .
# he 's been dead ten years . je suis suis . .
# he 's all right . je suis suis . .
# he 's in grave danger . je suis suis . .
# he 's making progress . je suis suis . .
# he 's about to leave . je suis suis . .
# he 's my half-brother . je suis suis . .
# he 's my friend . do you know him ? je suis suis . .
# he 's my best friend . je suis suis . .
# he 's addicted to heroin . je suis suis . .
# he 's come to make trouble . je suis suis . .
# he 's probably sleeping . je suis suis . .
# he 's a man now . je suis suis . .
# he 's old enough to be her father . je suis suis . .
# he 's a famous artist . je suis suis . .
# he 's right here . je suis suis . .
# he 's not here yet . je suis suis . .
# he 's now a college student . je suis suis . .
# he 's kind of handsome . je suis suis . .
# he 's able to speak japanese . je suis suis . .
# he 's a real man . je suis suis . .
# he 's a chinese-american . je suis suis . .
# he 's a dj . je suis suis . .
# he 's rough around the edges . je suis suis . .
# he 's probably wrong . je suis suis . .
# he 's sure that he 'll pass the next exam . je suis suis . .
# he 's eager to speak to you . je suis suis . .
# he 's gone into hiding . je suis suis . .
# he 's good at cards . je suis suis . .
# he 's angry at the world . je suis suis . .
# he 's an opera lover . je suis suis . .
# he 's just like his grandfather . je suis suis . .
# he 's a world-class scientist . je suis suis . .
# he 's ruthless . je suis suis . .
# he 's new in town . je suis suis . .
# he 's a scriptwriter . je suis suis . .
# he 's intelligent . je suis suis . .
# he 's an intelligent young man . je suis suis . .
# he 's highly intelligent . je suis suis . .
# he 's an interpreter in an international bank . je suis suis . .
# he 's out taking a walk . je suis suis . .
# he 's already left . je suis suis . .
# he 's cleaning his rifle . je suis suis . .
# he 's addicted to heroin . je suis suis . .
# he 's a married man . je suis suis . .
# he 's not in . je suis suis . .
# he 's very experienced . je suis suis . .
# he 's old and ugly . je suis suis . .
# he 's not always at home on sundays . je suis suis . .
# he 's a leading authority in his field . je suis suis . .
# he 's the king 's most trusted advisor . je suis suis . .
# he 's an accredited representative of the canadian government . je suis suis . .
# he 's my friend . je suis suis . .
# he 's my hero . je suis suis . .
# he 's wearing a new coat . je suis suis . .
# he 's overconfident . je suis suis . .
# he 's an expert at throwing knives . je suis suis . .
# he 's away on vacation . je suis suis . .
# he 's wearing a white cotton shirt . je suis suis . .
# he 's coming . je suis suis . .
# he 's got the flu . je suis suis . .
# he 's mad at everyone . je suis suis . .
# he 's about the same age as you are . je suis suis . .
# he 's not as tall as you are . je suis suis . .
# he 's raking it in . je suis suis . .
# he 's a fast walker . je suis suis . .
# he 's a loose cannon . je suis suis . .
# he 's still at work . je suis suis . .
# he 's my new friend . je suis suis . .
# he 's not in yet . je suis suis . .
# he 's my friend . je suis suis . .
# he 's attracted to asian women . je suis suis . .
# he 's an aristocrat . je suis suis . .
# he 's already a man . je suis suis . .
# he 's about the same age as you are . je suis suis . .
# he 's working on it . je suis suis . .
# he 's a freelance journalist . je suis suis . .
# he 's a sweet guy . je suis suis . .
# he 's a talented young director . je suis suis . .
# he 's not smart enough to add numbers in his head . je suis suis . .
# he 's three years older than i am . je suis suis . .
# he 's on his last legs . je suis suis . .
# he 's hiding in the closet . je suis suis . .
# he 's not stronger than me . je suis suis . .
# he 's very likely to be late . je suis suis . .
# he 's a big coward . je suis suis . .
# he 's three years older than me . je suis suis . .
# he 's gone into hiding . je suis suis . .
# he 's better at the piano than i am . je suis suis . .
# he 's known for that . je suis suis . .
# he 's swiss . je suis suis . .
# he 's an ex-con . je suis suis . .
# he 's spending too much time on the computer . je suis suis . .
# he 's looking at you . je suis suis . .
# he 's afraid that he might be late . je suis suis . .
# he 's going bald . je suis suis . .
# he 's not all there . je suis suis . .
# he 's waiting for you at home . je suis suis . .
# he 's very fond of reading . je suis suis . .
# he 's an independent thinker . je suis suis . .
# he 's a creationist . je suis suis . .
# he 's a bigot . je suis suis . .
# he 's a meth addict . je suis suis . .
# he 's ready to go . je suis suis . .
# he 's aware of his own faults . je suis suis . .
# he 's enjoying himself . je suis suis . .
# he 's on his way . je suis suis . .
# he 's outraged . je suis suis . .
# he 's a strange character . je suis suis . .
# he 's feeling really low . je suis suis . .
# he 's a construction worker . je suis suis . .
# he 's not married . je suis suis . .
# he 's fresh out of college . je suis suis . .
# he 's here for me . je suis suis . .
# he 's offered to help . je suis suis . .
# he 's a weak-willed man . je suis suis . .
# he 's certain to succeed . je suis suis . .
# he 's so thin that he looks like a skeleton . je suis suis . .
# he 's drunk . je suis suis . .
# he 's attracted to black women . je suis suis . .
# he 's a man of his word . je suis suis . .
# he 's not available . je suis suis . .
# he 's in the kitchen . je suis suis . .
# he 's busy and ca n't meet with you . je suis suis . .
# he 's a talented writer . je suis suis . .
# he 's at church right now . je suis suis . .
# he 's one of a kind . je suis suis . .
# he 's not a bad boy . je suis suis . .
# he 's been passing off my ideas as his . je suis suis . .
# he 's looking at you . je suis suis . .
# he 's crazy about her . je suis suis . .
# he 's not paying any attention to me . je suis suis . .
# he 's broke . je suis suis . .
# he 's painting his house . je suis suis . .
# he 's wet . je suis suis . .
# he 's saving up to go to college . je suis suis . .
# he 's now aboard the ship . je suis suis . .
# he 's a little rusty . je suis suis . .
# he 's not the brightest guy in the world . je suis suis . .
# he 's not a team player . je suis suis . .
# he 's too old for you . je suis suis . .
# he 's an asian-american . je suis suis . .
# he 's right behind you . je suis suis . .
# he 's what they call a walking encyclopedia . je suis suis . .
# he 's worried about his receding hairline . je suis suis . .
# he 's a talented writer . je suis suis . .
# he 's coming closer . je suis suis . .
# he 's lived here his entire life . je suis suis . .
# he 's good at this sort of thing . je suis suis . .
# he 's out of position . je suis suis . .
# he 's always at home on sundays . je suis suis . .
# he 's a man of his word , so you can count on him . je suis suis . .
# he 's a gardener . je suis suis . .
# he 's been teaching for 20 years . je suis suis . .
# he 's raking it in . je suis suis . .
# he 's the love of my life . je suis suis . .
# he 's a construction worker . je suis suis . .
# he 's not home . je suis suis . .
# he 's about the same age as you are . je suis suis . .
# he 's very open . je suis suis . .
# he 's skilled at videogames . je suis suis . .
# he 's a cold-hearted jerk . je suis suis . .
# he 's just trying to be popular . je suis suis . .
# he 's afraid of dogs . je suis suis . .
# he 's insecure . je suis suis . .
# he 's in hot water . je suis suis . .
# he 's as strong as a horse . je suis suis . .
# he 's a lovely young man . je suis suis . .
# he 's old enough to be her grandfather . je suis suis . .
# he 's fresh out of college . je suis suis . .
# he 's a widower with three small children to take care of . je suis suis . .
# he 's too busy . je suis suis . .
# he 's addicted . je suis suis . .
# he 's a community leader . je suis suis . .
# he 's a bit rough around the edges . je suis suis . .
# he 's really good looking . je suis suis . .
# he 's an italian teacher . je suis suis . .
# he 's taller than me . je suis suis . .
# he 's very ill . je suis suis . .
# he 's not in the mood . je suis suis . .
# he 's an outlaw . je suis suis . .
# he 's reading a novel now . je suis suis . .
# he 's running for congress . je suis suis . .
# he 's not in the least interested in what is happening in the world . je suis suis . .
# he 's very skeptical . je suis suis . .
# he 's in good physical condition . je suis suis . .
# he 's attracted to asian girls . je suis suis . .
# he 's not stupid . je suis suis . .
# he 's now on the boat . je suis suis . .
# he 's back from his travels in central asia . je suis suis . .
# he 's my best friend . we 're like brothers . je suis suis . .
# he 's young and healthy . je suis suis . .
# he 's a bit rough around the edges . je suis suis . .
# he 's much more into her than she is into him . je suis suis . .
# he 's not the same man he used to be . je suis suis . .
# he 's a high school student . je suis suis . .
# he 's very likely to come . je suis suis . .
# he 's the type who does n't worry about details . je suis suis . .
# he 's an undergrad . je suis suis . .
# he 's never satisfied . je suis suis . .
# he 's got a rap sheet as long as my arm . je suis suis . .
# he 's not working much at the moment . je suis suis . .
# he 's leaving for tokyo tomorrow . je suis suis . .
# he 's obsessed with cleanliness . je suis suis . .
# he 's cleaning out his closet . je suis suis . .
# he 's smoking more than ever . je suis suis . .
# he 's fed up with socializing . je suis suis . .
# he 's really in good shape . je suis suis . .
# he 's getting cold feet . je suis suis . .
# he 's an old timer . je suis suis . .
# he 's addicted to heroin . je suis suis . .
# he 's always changing his mind . je suis suis . .
# he 's one of the best . je suis suis . .
# he 's very proud of his custom motorcycle . je suis suis . .
# he 's english , but lives in india . je suis suis . .
# he 's totally dependent on his parents . je suis suis . .
# he 's insecure . je suis suis . .
# he 's kind of cute . je suis suis . .
# he 's very sloppy in his dress . je suis suis . .
# he 's my older brother . je suis suis . .
# he 's faking . je suis suis . .
# he 's depressed . je suis suis . .
# he 's not a liar . je suis suis . .
# he 's getting soft in his old age . je suis suis . .
# he 's loaded . je suis suis . .
# he 's not lazy . on the contrary , i think he 's a hard worker . je suis suis . .
# he 's addicted to heroin . je suis suis . .
# he 's a junior employee . je suis suis . .
# he 's a chain smoker . je suis suis . .
# he 's studying . je suis suis . .
# he 's a gambler . je suis suis . .
# he 's a bit shy . je suis suis . .
# he 's too old for you . je suis suis . .
# he 's bound to notice your mistake . je suis suis . .
# he 's always dissatisfied . je suis suis . .
# he 's not at home . je suis suis . .
# he 's a total wreck . je suis suis . .
# he 's your friend . je suis suis . .
# he 's about to go . je suis suis . .
# he is mad about music . je suis suis . .
# he is n't actually the manager . je suis suis . .
# he is playing in his room . je suis suis . .
# he is far from happy . je suis suis . .
# he is a very imaginative writer . je suis suis . .
# he is complaining about something or other all the time . je suis suis . .
# he is by far the best student . je suis suis . .
# he is not as lazy a student as you think . je suis suis . .
# he is beyond hope . je suis suis . .
# he is ahead of us in mathematics . je suis suis . .
# he is such a show off . je suis suis . .
# he is not man to lose heart at a single failure . je suis suis . .
# he is powerful . je suis suis . .
# he is reasonable in his demands . je suis suis . .
# he is something of an artist . je suis suis . .
# he is hard to please . je suis suis . .
# he is used to that type of situation . je suis suis . .
# he is a handsome man . je suis suis . .
# he is not at all a gentleman . je suis suis . .
# he is making cookies . je suis suis . .
# he is outgoing . je suis suis . .
# he is a good singer . je suis suis . .
# he is in trouble . je suis suis . .
# he is eager to go there . je suis suis . .
# he is an honest man . je suis suis . .
# he is full of ambition . je suis suis . .
# he is very afraid of dogs . je suis suis . .
# he is such a lazy fellow . je suis suis . .
# he is an authority on china . je suis suis . .
# he is well off . je suis suis . .
# he is not the shy boy he used to be . je suis suis . .
# he is very particular about his food . je suis suis . .
# he is watching tv . je suis suis . .
# he is one of the greatest artists in japan . je suis suis . .
# he is a lazy student . je suis suis . .
# he is a man of ability . je suis suis . .
# he is running . je suis suis . .
# he is my close friend . je suis suis . .
# he is just a kid . je suis suis . .
# he is canadian . je suis suis . .
# he is popular with his men . je suis suis . .
# he is n't at home , is he ? je suis suis . .
# he is a tennis champion . je suis suis . .
# he is taking a walk . je suis suis . .
# he is saving money for a trip abroad . je suis suis . .
# he is furious at what they have done to him . je suis suis . .
# he is about to die . je suis suis . .
# he is afraid of snakes . je suis suis . .
# he is not wearing a hat . je suis suis . .
# he is not what he seems . je suis suis . .
# he is apparently responsible for it . je suis suis . .
# he is subject to fits of anger . je suis suis . .
# he is absent from school today . je suis suis . .
# he is very angry . je suis suis . .
# he is teaching me . je suis suis . .
# he is by far the best baseball player at our school . je suis suis . .
# he is in excellent physical condition . je suis suis . .
# he is never lazy . je suis suis . .
# he is a harsh critic . je suis suis . .
# he is tremendously handsome . je suis suis . .
# he is my teacher . je suis suis . .
# he is present at the meeting . je suis suis . .
# he is seeking a new position . je suis suis . .
# he is unmarried . je suis suis . .
# he is n't married . je suis suis . .
# he is smelling the soup . je suis suis . .
# he is old enough to drink . je suis suis . .
# he is suffering from a cold . je suis suis . .
# he is very slow at making friends with anybody . je suis suis . .
# he is intelligent . je suis suis . .
# he is leaving for new york next week . je suis suis . .
# he is eight . je suis suis . .
# he is dead drunk . je suis suis . .
# he is an environmentalist . je suis suis . .
# he is studying at his desk . je suis suis . .
# he is anxious to know the result . je suis suis . .
# he is standing on the stage . je suis suis . .
# he is a biologist . je suis suis . .
# he is not my son , but my nephew . je suis suis . .
# he is a lazy fellow . je suis suis . .
# he is reading . je suis suis . .
# he is a good doctor . je suis suis . .
# he is proficient in farsi . je suis suis . .
# he is a big eater . je suis suis . .
# he is no match for his wife . je suis suis . .
# he is about your age . je suis suis . .
# he is fluent in chinese . je suis suis . .
# he is not as tall as his father . je suis suis . .
# he is not very good at mathematics . je suis suis . .
# he is by far the best student . je suis suis . .
# he is a true gentleman . je suis suis . .
# he is well acquainted with the history of england . je suis suis . .
# he is running short of funds . je suis suis . .
# he is an unsung hero . je suis suis . .
# he is sitting on the chair . je suis suis . .
# he is a heroin addict . je suis suis . .
# he is not much better , and there is a little hope of recovery . je suis suis . .
# he is smart . je suis suis . .
# he is not religious . je suis suis . .
# he is by far the wisest of the three . je suis suis . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [162], line 23
#      19     return " ".join(words)
#      22 for sent in df.source_language:
# ---> 23     print(sent, translate(sent))
#
# Cell In [162], line 9, in translate(sent)
#       7 hidden = hidden.unsqueeze(0)
#       8 y = torch.tensor([target_vocab.begin_seq_idx]).unsqueeze(0)
# ----> 9 output, _ = decoder.generate(y, hidden=hidden, size=100)
#      10 output = output.squeeze().argmax(dim=1)
#      11 words = []
#
# Cell In [142], line 25, in DecoderRNN.generate(self, input, hidden, size)
#      23 outputs = [output]
#      24 for _ in range(size - 1):
# ---> 25     output, hidden = self.rnn(output, hidden)
#      26     outputs.append(output)
#      27     output = F.relu(output)
#
# File ~/opt/miniconda3/envs/nlp/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/miniconda3/envs/nlp/lib/python3.9/site-packages/torch/nn/modules/rnn.py:950, in GRU.forward(self, input, hx)
#     948 self.check_forward_args(input, hx, batch_sizes)
#     949 if batch_sizes is None:
# --> 950     result = _VF.gru(input, hx, self._flat_weights, self.bias, self.num_layers,
#     951                      self.dropout, self.training, self.bidirectional, self.batch_first)
#     952 else:
#     953     result = _VF.gru(input, batch_sizes, hx, self._flat_weights, self.bias,
#     954                      self.num_layers, self.dropout, self.training, self.bidirectional)
#
# KeyboardInterrupt:

# %% [markdown]
# # Evaluation
